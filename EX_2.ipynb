# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\HDC0422089\Downloads\inventory_dataset - inventory_dataset.csv")

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883              588.0          292.0           161.0
# ...

# %%
null_columns = df.columns[df.isnull().any()]

# %%
null_columns
# Out:
# Index(['Purchase_Price', 'Sale_Price', 'Quantity_In_Stock', 'Reorder_Level',
#        'Units_On_Order'],
#       dtype='object')

# %%
median_values = df['Purchase_Price'].median()
df['Purchase_Price'].fillna(median_values, inplace = True)
# Out:
# C:\Users\HDC0422089\AppData\Local\Temp\ipykernel_5644\2920355979.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Purchase_Price'].fillna(median_values, inplace = True)

# %%
df
# Out:
#     Product_ID Product_Name         Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad         Clothing  Supplier D          339.75
# 1        P0002    Doohickey         Clothing  Supplier C          253.17
# 2        P0003  Thingamajig         Clothing  Supplier B          253.17
# 3        P0004    Doohickey         Clothing  Supplier A          253.17
# 4        P0005    Doohickey             Toys  Supplier E          228.75
# ..         ...          ...              ...         ...             ...
# 995      P0996       Gadget      Electronics  Supplier D          350.37
# 996      P0997       Widget             Toys  Supplier E          117.17
# 997      P0998       Widget      Electronics  Supplier C          301.70
# 998      P0999       Doodad             Toys  Supplier B          139.67
# 999      P1000  Thingamajig  Office Supplies  Supplier D          253.17
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'mean')

# %%
sale_price_reshaped = df[['Sale_Price']].values

# %%
df[['Sale_Price']] = imputer.fit_transform(sale_price_reshaped)

# %%
df
# Out:
#     Product_ID Product_Name         Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad         Clothing  Supplier D          339.75
# 1        P0002    Doohickey         Clothing  Supplier C          253.17
# 2        P0003  Thingamajig         Clothing  Supplier B          253.17
# 3        P0004    Doohickey         Clothing  Supplier A          253.17
# 4        P0005    Doohickey             Toys  Supplier E          228.75
# ..         ...          ...              ...         ...             ...
# 995      P0996       Gadget      Electronics  Supplier D          350.37
# 996      P0997       Widget             Toys  Supplier E          117.17
# 997      P0998       Widget      Electronics  Supplier C          301.70
# 998      P0999       Doodad             Toys  Supplier B          139.67
# 999      P1000  Thingamajig  Office Supplies  Supplier D          253.17
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# ...

# %%
df
# Out:
#     Product_ID Product_Name         Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad         Clothing  Supplier D          339.75
# 1        P0002    Doohickey         Clothing  Supplier C          253.17
# 2        P0003  Thingamajig         Clothing  Supplier B          253.17
# 3        P0004    Doohickey         Clothing  Supplier A          253.17
# 4        P0005    Doohickey             Toys  Supplier E          228.75
# ..         ...          ...              ...         ...             ...
# 995      P0996       Gadget      Electronics  Supplier D          350.37
# 996      P0997       Widget             Toys  Supplier E          117.17
# 997      P0998       Widget      Electronics  Supplier C          301.70
# 998      P0999       Doodad             Toys  Supplier B          139.67
# 999      P1000  Thingamajig  Office Supplies  Supplier D          253.17
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883              588.0          292.0           161.0
# ...

# %%
Q1 = df['Sale_Price'].quantile(0.25)
Q2 = df['Sale_Price'].quantile(0.75)
IQR = Q2 - Q1
LB = Q1 - 1.5*IQR
UB = Q2 + 1.5*IQR

sales_price = df[(df['Sale_Price'] >= LB) & (df['Sale_Price'] <= UB)]

# %%
sales_price
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883              588.0          292.0           161.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Quantity_In_Stock'] = scaler.fit_transform(df[['Quantity_In_Stock']])

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883           0.585859          292.0           161.0
# ...

# %%
df['Quantity_In_Stock'] = (df['Quantity_In_Stock'] * 100).astype(int)

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883                 58          292.0           161.0
# ...

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883                 58          292.0           161.0
# ...

# %%
df['Discontinued'] = df['Discontinued'].astype(int)

# %%
df
# Out:
#     Product_ID Product_Name     Category    Supplier  Purchase_Price  \
# 0        P0001       Doodad     Clothing  Supplier D          339.75
# 1        P0002    Doohickey     Clothing  Supplier C          253.17
# 2        P0003  Thingamajig     Clothing  Supplier B          253.17
# 3        P0004    Doohickey     Clothing  Supplier A          253.17
# 4        P0005    Doohickey         Toys  Supplier E          228.75
# ..         ...          ...          ...         ...             ...
# 993      P0994       Gadget     Clothing  Supplier A          253.17
# 995      P0996       Gadget  Electronics  Supplier D          350.37
# 996      P0997       Widget         Toys  Supplier E          117.17
# 997      P0998       Widget  Electronics  Supplier C          301.70
# 998      P0999       Doodad         Toys  Supplier B          139.67
#
#      Sale_Price  Quantity_In_Stock  Reorder_Level  Units_On_Order  \
# 0    351.926883                 58          292.0           161.0
# ...

# %%
df.to_csv('cleaned_inventory.csv', index=False)

# %%
from IPython.display import FileLink
FileLink('cleaned_inventory.csv')
# Out:
# C:\Users\HDC0422089\cleaned_inventory.csv
